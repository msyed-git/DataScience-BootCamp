# %%
from sqlalchemy import create_engine 
import pandas as pd

engine = create_engine('sqlite:///sqlite_db_pythonsqlite.db')

# %%
with engine.connect() as con, con.begin():  
    Bookings = pd.read_sql_table("Bookings", con) 
    
Bookings
# Out:
# C:\Users\msyed\Anaconda3\lib\site-packages\pandas\io\sql.py:1627: SAWarning: Could not instantiate type <class 'sqlalchemy.sql.sqltypes.INTEGER'> with reflected arguments ['4']; using no arguments.
#   self.meta.reflect(bind=self.con, only=[table_name])
# C:\Users\msyed\Anaconda3\lib\site-packages\pandas\io\sql.py:1627: SAWarning: Could not instantiate type <class 'sqlalchemy.sql.sqltypes.INTEGER'> with reflected arguments ['1']; using no arguments.
#   self.meta.reflect(bind=self.con, only=[table_name])
# C:\Users\msyed\Anaconda3\lib\site-packages\pandas\io\sql.py:1627: SAWarning: Could not instantiate type <class 'sqlalchemy.sql.sqltypes.INTEGER'> with reflected arguments ['2']; using no arguments.
#   self.meta.reflect(bind=self.con, only=[table_name])
#       bookid  facid  memid            starttime  slots
# 0          0      3      1  2012-07-03 11:00:00      2
# 1          1      4      1  2012-07-03 08:00:00      2
# 2          2      6      0  2012-07-03 18:00:00      2
# ...

# %%
with engine.connect() as con, con.begin():  
    Facilities = pd.read_sql_table("Facilities", con)
Facilities
# Out:
# C:\Users\msyed\Anaconda3\lib\site-packages\pandas\io\sql.py:1627: SAWarning: Could not instantiate type <class 'sqlalchemy.sql.sqltypes.INTEGER'> with reflected arguments ['1']; using no arguments.
#   self.meta.reflect(bind=self.con, only=[table_name])
# C:\Users\msyed\Anaconda3\lib\site-packages\pandas\io\sql.py:1627: SAWarning: Could not instantiate type <class 'sqlalchemy.sql.sqltypes.INTEGER'> with reflected arguments ['5']; using no arguments.
#   self.meta.reflect(bind=self.con, only=[table_name])
# C:\Users\msyed\Anaconda3\lib\site-packages\pandas\io\sql.py:1627: SAWarning: Could not instantiate type <class 'sqlalchemy.sql.sqltypes.INTEGER'> with reflected arguments ['4']; using no arguments.
#   self.meta.reflect(bind=self.con, only=[table_name])
#    facid             name  membercost  guestcost  initialoutlay  \
# 0      0   Tennis Court 1         5.0       25.0          10000
# 1      1   Tennis Court 2         5.0       25.0           8000
# ...

# %%
with engine.connect() as con, con.begin():  
    Members = pd.read_sql_table("Members", con)
Members
# Out:
# C:\Users\msyed\Anaconda3\lib\site-packages\pandas\io\sql.py:1627: SAWarning: Could not instantiate type <class 'sqlalchemy.sql.sqltypes.INTEGER'> with reflected arguments ['2']; using no arguments.
#   self.meta.reflect(bind=self.con, only=[table_name])
# C:\Users\msyed\Anaconda3\lib\site-packages\pandas\io\sql.py:1627: SAWarning: Could not instantiate type <class 'sqlalchemy.sql.sqltypes.INTEGER'> with reflected arguments ['5']; using no arguments.
#   self.meta.reflect(bind=self.con, only=[table_name])
#     memid            surname  firstname  \
# 0       0              GUEST      GUEST
# 1       1              Smith     Darren
# 2       2              Smith      Tracy
# 3       3             Rownam        Tim
# 4       4           Joplette     Janice
# 5       5            Butters     Gerald
# 6       6              Tracy     Burton
# 7       7               Dare      Nancy
# 8       8             Boothe        Tim
# 9       9           Stibbons     Ponder
# ...

# %%
Q10 = pd.read_sql_query("SELECT name, sum(case when memid = 0 then slots * guestcost else slots * membercost end) as Revenue FROM Bookings LEFT JOIN Facilities using(facid) GROUP BY name HAVING Revenue < 1000",engine)
# list of facilities with a total revenue less than 1000
Q10
# Out:
#             name  Revenue
# 0     Pool Table      270
# 1  Snooker Table      240
# 2   Table Tennis      180

# %%
Q11 = pd.read_sql_query("SELECT m.membername, mm.firstname || ' ' || mm.surname AS Recommended_BY FROM (SELECT firstname || ' ' || surname AS membername, recommendedby FROM Members WHERE recommendedby > 0 ORDER BY surname ASC, firstname ASC) AS m INNER JOIN Members as mm ON m.recommendedby = mm.memid ORDER BY mm.surname ASC, mm.firstname ASC", engine)
#Produce a report of members and who recommended them in alphabetic surname,firstname order
Q11
# Out:
#                  membername     Recommended_BY
# 0          Ramnaresh Sarwin     Florence Bader
# 1               Joan Coplin      Timothy Baker
# 2           Matthew Genting     Gerald Butters
# 3             Timothy Baker     Jemima Farrell
# 4              David Pinker     Jemima Farrell
# 5          Henrietta Rumney    Matthew Genting
# 6             Douglas Jones        David Jones
# 7                Nancy Dare    Janice Joplette
# 8               David Jones    Janice Joplette
# 9                 John Hunt  Millicent Purview
# 10               Tim Boothe         Tim Rownam
# 11          Janice Joplette       Darren Smith
# 12           Gerald Butters       Darren Smith
# 13             Charles Owen       Darren Smith
# 14               Jack Smith       Darren Smith
# 15           Anna Mackenzie       Darren Smith
# 16  Henry Worthington-Smyth        Tracy Smith
# 17        Millicent Purview        Tracy Smith
# 18            Erica Crumpet        Tracy Smith
# ...

# %%
Q12 = pd.read_sql_query("SELECT f.name, m.firstname || ' ' || m.surname AS membername,   COUNT(*) AS usedbymember FROM Bookings AS b INNER JOIN Facilities AS f USING(facid) INNER JOIN members AS m USING(memid) WHERE b.memid != 0 GROUP by f.name, membername ",engine)
##Find the facilities with their usage by member, but not guests 
Q12
# Out:
#                 name        membername  usedbymember
# 0    Badminton Court    Anna Mackenzie            30
# 1    Badminton Court        Anne Baker            10
# 2    Badminton Court      Burton Tracy             2
# 3    Badminton Court      Charles Owen             6
# 4    Badminton Court      Darren Smith           132
# ..               ...               ...           ...
# 197   Tennis Court 2  Ramnaresh Sarwin            11
# 198   Tennis Court 2        Tim Boothe            52
# 199   Tennis Court 2        Tim Rownam             6
# 200   Tennis Court 2     Timothy Baker             7
# 201   Tennis Court 2       Tracy Smith             2
#
# [202 rows x 3 columns]

# %%
Q13 = pd.read_sql_query("SELECT f.name, strftime('%m', starttime) as month,   COUNT(*) AS monthlyusage FROM Bookings AS b INNER JOIN Facilities AS f USING(facid) WHERE b.memid != 0 GROUP by month, f.name ",engine)
#Q13: Find the facilities usage by month, but not guests 
Q13
# Out:
#                name month  monthlyusage
# 0   Badminton Court    07            51
# 1    Massage Room 1    07            77
# 2    Massage Room 2    07             4
# 3        Pool Table    07           103
# 4     Snooker Table    07            68
# 5      Squash Court    07            23
# 6      Table Tennis    07            48
# 7    Tennis Court 1    07            65
# 8    Tennis Court 2    07            41
# 9   Badminton Court    08           132
# 10   Massage Room 1    08           153
# 11   Massage Room 2    08             9
# 12       Pool Table    08           272
# 13    Snooker Table    08           154
# 14     Squash Court    08            85
# 15     Table Tennis    08           143
# 16   Tennis Court 1    08           111
# 17   Tennis Court 2    08           109
# 18  Badminton Court    09           161
# 19   Massage Room 1    09           191
# 20   Massage Room 2    09            14
# 21       Pool Table    09           408
# ...
